# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
salary_list = pd.read_csv('https://raw.githubusercontent.com/randyleonard99/digitalframeworks-spring2020/master/class6/Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %%
salary_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33183 entries, 0 to 33182
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               33183 non-null  object
#  1   Job Titles         33183 non-null  object
#  2   Department         33183 non-null  object
#  3   Full or Part-Time  33183 non-null  object
#  4   Salary or Hourly   33183 non-null  object
#  5   Typical Hours      8022 non-null   float64
#  6   Annual Salary      25161 non-null  float64
#  7   Hourly Rate        8022 non-null   float64
#  8   annualized         33183 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 2.3+ MB

# %%
salary_list.mean()
# Out:
# Typical Hours       34.507604
# Annual Salary    86786.999790
# Hourly Rate         32.788558
# annualized       80482.368810
# dtype: float64

# %%
salary_list.median()
# Out:
# Typical Hours       40.0
# Annual Salary    90024.0
# Hourly Rate         35.6
# annualized       87006.0
# dtype: float64

# %%
salary_list.min()
# Out:
# Name                            AARON,  JEFFERY M
# Job Titles           1ST DEPUTY INSPECTOR GENERAL
# Department                           ADMIN HEARNG
# Full or Part-Time                               F
# Salary or Hourly                           Hourly
# Typical Hours                                  10
# Annual Salary                                7200
# Hourly Rate                                  2.65
# annualized                                   2650
# dtype: object

# %%
salary_list.max()
# Out:
# Name                 ZYSKOWSKI,  DARIUSZ
# Job Titles           ZONING PLAN EXAMINER
# Department                    WATER MGMNT
# Full or Part-Time                       P
# Salary or Hourly                   Salary
# Typical Hours                          40
# Annual Salary                      300000
# Hourly Rate                           109
# annualized                         300000
# dtype: object

# %%
salary_list.head()
# Out:
#                   Name                      Job Titles      Department  \
# 0     EVANS,  GINGER S        COMMISSIONER OF AVIATION        AVIATION
# 1    JOHNSON,  EDDIE T        SUPERINTENDENT OF POLICE          POLICE
# 2      EMANUEL,  RAHM                            MAYOR  MAYOR'S OFFICE
# 3    SANTIAGO,  JOSE A               FIRE COMMISSIONER            FIRE
# 4  FORD II,  RICHARD C  FIRST DEPUTY FIRE COMMISSIONER            FIRE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN       300000.0
# 1                 F           Salary            NaN       260004.0
# 2                 F           Salary            NaN       216210.0
# 3                 F           Salary            NaN       202728.0
# 4                 F           Salary            NaN       197736.0
#
#    Hourly Rate  annualized
# 0          NaN    300000.0
# 1          NaN    260004.0
# 2          NaN    216210.0
# ...

# %%
salary_list['Department']
# Out:
# 0                AVIATION
# 1                  POLICE
# 2          MAYOR'S OFFICE
# 3                    FIRE
# 4                    FIRE
#                ...
# 33178    FAMILY & SUPPORT
# 33179    FAMILY & SUPPORT
# 33180    FAMILY & SUPPORT
# 33181    FAMILY & SUPPORT
# 33182    FAMILY & SUPPORT
# Name: Department, Length: 33183, dtype: object

# %%
salary_list.Department.value_counts()
# Out:
# POLICE                   13414
# FIRE                      4641
# STREETS & SAN             2198
# OEMC                      2102
# WATER MGMNT               1879
# AVIATION                  1629
# TRANSPORTN                1140
# PUBLIC LIBRARY            1015
# GENERAL SERVICES           980
# FAMILY & SUPPORT           615
# FINANCE                    560
# HEALTH                     488
# CITY COUNCIL               411
# LAW                        407
# BUILDINGS                  269
# COMMUNITY DEVELOPMENT      207
# BUSINESS AFFAIRS           171
# COPA                       116
# BOARD OF ELECTION          107
# DoIT                        99
# PROCUREMENT                 92
# INSPECTOR GEN               87
# MAYOR'S OFFICE              85
# CITY CLERK                  84
# ANIMAL CONTRL               81
# HUMAN RESOURCES             79
# CULTURAL AFFAIRS            65
# BUDGET & MGMT               46
# ADMIN HEARNG                39
# DISABILITIES                28
# ...

# %%
my_prop = 'POLICE.'

# %%
salary_list[salary_list.Department == my_prop]
# Out:
# Empty DataFrame
# Columns: [Name, Job Titles, Department, Full or Part-Time, Salary or Hourly, Typical Hours, Annual Salary, Hourly Rate, annualized]
# Index: []

# %%
my_list = salary_list[salary_list.Department == my_prop]

# %%
my_list.head()
# Out:
# Empty DataFrame
# Columns: [Name, Job Titles, Department, Full or Part-Time, Salary or Hourly, Typical Hours, Annual Salary, Hourly Rate, annualized]
# Index: []

# %%
my_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               0 non-null      object
#  1   Job Titles         0 non-null      object
#  2   Department         0 non-null      object
#  3   Full or Part-Time  0 non-null      object
#  4   Salary or Hourly   0 non-null      object
#  5   Typical Hours      0 non-null      float64
#  6   Annual Salary      0 non-null      float64
#  7   Hourly Rate        0 non-null      float64
#  8   annualized         0 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 0.0+ bytes

# %%
salary_list['Full or Part-Time']
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        F
#         ..
# 33178    P
# 33179    P
# 33180    P
# 33181    P
# 33182    P
# Name: Full or Part-Time, Length: 33183, dtype: object

# %%
salary_list['Full or Part-Time'].value_counts()
# Out:
# F    31090
# P     2093
# Name: Full or Part-Time, dtype: int64

# %%
new_prop = 'F'

# %%
new_filter=salary_list[salary_list['Full or Part-Time'] == new_prop]

# %%
new_filter
# Out:
#                            Name                      Job Titles  \
# 0              EVANS,  GINGER S        COMMISSIONER OF AVIATION
# 1             JOHNSON,  EDDIE T        SUPERINTENDENT OF POLICE
# 2               EMANUEL,  RAHM                            MAYOR
# 3             SANTIAGO,  JOSE A               FIRE COMMISSIONER
# 4           FORD II,  RICHARD C  FIRST DEPUTY FIRE COMMISSIONER
# ...                         ...                             ...
# 32326        BURKS,  BRITTANY S                 ALDERMANIC AIDE
# 32336         DUKES,  DOROTHY L                 ALDERMANIC AIDE
# 32337           TAYLOR,  INES W                 ALDERMANIC AIDE
# 32821  TERRELL HART,  ADRIENNE                  ALDERMANIC AIDE
# 32934        MARVIN,  ZACHARY R           GENERAL LABORER - DSS
#
#            Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            AVIATION                 F           Salary            NaN
# ...

# %%
new_filter.min()
# Out:
# Name                            AARON,  JEFFERY M
# Job Titles           1ST DEPUTY INSPECTOR GENERAL
# Department                           ADMIN HEARNG
# Full or Part-Time                               F
# Salary or Hourly                           Hourly
# Typical Hours                                  10
# Annual Salary                               12840
# Hourly Rate                                   9.5
# annualized                                   9750
# dtype: object

# %%
new_filter.max()
# Out:
# Name                 ZYSKOWSKI,  DARIUSZ
# Job Titles           ZONING PLAN EXAMINER
# Department                    WATER MGMNT
# Full or Part-Time                       F
# Salary or Hourly                   Salary
# Typical Hours                          40
# Annual Salary                      300000
# Hourly Rate                           109
# annualized                         300000
# dtype: object

# %%
new_filter.mean()
# Out:
# Typical Hours       39.905581
# Annual Salary    86793.064181
# Hourly Rate         38.287220
# annualized       84825.366170
# dtype: float64

# %%
new_filter.head()
# Out:
#                   Name                      Job Titles      Department  \
# 0     EVANS,  GINGER S        COMMISSIONER OF AVIATION        AVIATION
# 1    JOHNSON,  EDDIE T        SUPERINTENDENT OF POLICE          POLICE
# 2      EMANUEL,  RAHM                            MAYOR  MAYOR'S OFFICE
# 3    SANTIAGO,  JOSE A               FIRE COMMISSIONER            FIRE
# 4  FORD II,  RICHARD C  FIRST DEPUTY FIRE COMMISSIONER            FIRE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN       300000.0
# 1                 F           Salary            NaN       260004.0
# 2                 F           Salary            NaN       216210.0
# 3                 F           Salary            NaN       202728.0
# 4                 F           Salary            NaN       197736.0
#
#    Hourly Rate  annualized
# 0          NaN    300000.0
# 1          NaN    260004.0
# 2          NaN    216210.0
# ...

# %%
new_filter.median()
# Out:
# Typical Hours       40.00
# Annual Salary    90024.00
# Hourly Rate         36.21
# annualized       87006.00
# dtype: float64

# %%
new_filter.nsmallest(5,'annualized')
# Out:
#                            Name             Job Titles     Department  \
# 32934        MARVIN,  ZACHARY R  GENERAL LABORER - DSS  STREETS & SAN
# 32821  TERRELL HART,  ADRIENNE         ALDERMANIC AIDE   CITY COUNCIL
# 32336         DUKES,  DOROTHY L        ALDERMANIC AIDE   CITY COUNCIL
# 32337           TAYLOR,  INES W        ALDERMANIC AIDE   CITY COUNCIL
# 32326        BURKS,  BRITTANY S        ALDERMANIC AIDE   CITY COUNCIL
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 32934                 F           Hourly           10.0            NaN
# 32821                 F           Salary            NaN        12840.0
# 32336                 F           Salary            NaN        15000.0
# 32337                 F           Salary            NaN        15000.0
# 32326                 F           Salary            NaN        15012.0
#
#        Hourly Rate  annualized
# 32934         19.5      9750.0
# 32821          NaN     12840.0
# ...

# %%
new_filter.nlargest(5,'annualized')
# Out:
#                   Name                      Job Titles      Department  \
# 0     EVANS,  GINGER S        COMMISSIONER OF AVIATION        AVIATION
# 1    JOHNSON,  EDDIE T        SUPERINTENDENT OF POLICE          POLICE
# 2      EMANUEL,  RAHM                            MAYOR  MAYOR'S OFFICE
# 3    SANTIAGO,  JOSE A               FIRE COMMISSIONER            FIRE
# 4  FORD II,  RICHARD C  FIRST DEPUTY FIRE COMMISSIONER            FIRE
#
#   Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                 F           Salary            NaN       300000.0
# 1                 F           Salary            NaN       260004.0
# 2                 F           Salary            NaN       216210.0
# 3                 F           Salary            NaN       202728.0
# 4                 F           Salary            NaN       197736.0
#
#    Hourly Rate  annualized
# 0          NaN    300000.0
# 1          NaN    260004.0
# 2          NaN    216210.0
# ...

# %%
salary_list['Department']
# Out:
# 0                AVIATION
# 1                  POLICE
# 2          MAYOR'S OFFICE
# 3                    FIRE
# 4                    FIRE
#                ...
# 33178    FAMILY & SUPPORT
# 33179    FAMILY & SUPPORT
# 33180    FAMILY & SUPPORT
# 33181    FAMILY & SUPPORT
# 33182    FAMILY & SUPPORT
# Name: Department, Length: 33183, dtype: object

# %%
salary_list['Department'].value_counts()
# Out:
# POLICE                   13414
# FIRE                      4641
# STREETS & SAN             2198
# OEMC                      2102
# WATER MGMNT               1879
# AVIATION                  1629
# TRANSPORTN                1140
# PUBLIC LIBRARY            1015
# GENERAL SERVICES           980
# FAMILY & SUPPORT           615
# FINANCE                    560
# HEALTH                     488
# CITY COUNCIL               411
# LAW                        407
# BUILDINGS                  269
# COMMUNITY DEVELOPMENT      207
# BUSINESS AFFAIRS           171
# COPA                       116
# BOARD OF ELECTION          107
# DoIT                        99
# PROCUREMENT                 92
# INSPECTOR GEN               87
# MAYOR'S OFFICE              85
# CITY CLERK                  84
# ANIMAL CONTRL               81
# HUMAN RESOURCES             79
# CULTURAL AFFAIRS            65
# BUDGET & MGMT               46
# ADMIN HEARNG                39
# DISABILITIES                28
# ...

# %%
gk = new_filter.groupby('Department')

# %%
gk

# %%
new_filter.groupby('Department')['annualized'].sum().to_frame().reset_index().sort_values(by='annualized')
# Out:
#                Department    annualized
# 24      LICENSE APPL COMM  8.442000e+04
# 28           POLICE BOARD  1.722720e+05
# 4         BOARD OF ETHICS  7.604880e+05
# 20        HUMAN RELATIONS  1.517112e+06
# 33              TREASURER  2.020323e+06
# 13           DISABILITIES  2.348628e+06
# 0            ADMIN HEARNG  3.068664e+06
# 5           BUDGET & MGMT  4.086308e+06
# 1           ANIMAL CONTRL  4.104252e+06
# 12       CULTURAL AFFAIRS  5.340110e+06
# 3       BOARD OF ELECTION  5.729652e+06
# 8              CITY CLERK  5.955549e+06
# 21        HUMAN RESOURCES  6.017292e+06
# 22          INSPECTOR GEN  6.949104e+06
# 29            PROCUREMENT  7.641448e+06
# 25         MAYOR'S OFFICE  7.805333e+06
# 11                   COPA  8.833404e+06
# 14                   DoIT  9.897828e+06
# 7        BUSINESS AFFAIRS  1.321464e+07
# 10  COMMUNITY DEVELOPMENT  1.802539e+07
# 9            CITY COUNCIL  2.273308e+07
# 15       FAMILY & SUPPORT  2.625243e+07
# ...

# %%
new_filter.groupby('Department')['annualized'].agg(['min', 'max'])
# Out:
#                            min       max
# Department
# ADMIN HEARNG           41640.0  156420.0
# ANIMAL CONTRL          41832.0  130008.0
# AVIATION               22750.0  300000.0
# BOARD OF ELECTION      27912.0  133740.0
# BOARD OF ETHICS        73944.0  135672.0
# BUDGET & MGMT          22750.0  169992.0
# BUILDINGS              40392.0  157092.0
# BUSINESS AFFAIRS       38376.0  157092.0
# CITY CLERK             38376.0  133545.0
# CITY COUNCIL           12840.0  168264.0
# COMMUNITY DEVELOPMENT  42108.0  175020.0
# COPA                   31872.0  161856.0
# CULTURAL AFFAIRS       19250.0  155040.0
# DISABILITIES           38100.0  138420.0
# DoIT                   60972.0  154992.0
# FAMILY & SUPPORT       36204.0  175002.0
# FINANCE                36204.0  165000.0
# FIRE                   37980.0  202728.0
# GENERAL SERVICES       33552.0  163896.0
# HEALTH                 38376.0  190750.0
# HUMAN RELATIONS        70620.0  125004.0
# ...

# %%
new_filter.groupby('Department')['annualized'].agg(['max', 'min'])
# Out:
#                             max      min
# Department
# ADMIN HEARNG           156420.0  41640.0
# ANIMAL CONTRL          130008.0  41832.0
# AVIATION               300000.0  22750.0
# BOARD OF ELECTION      133740.0  27912.0
# BOARD OF ETHICS        135672.0  73944.0
# BUDGET & MGMT          169992.0  22750.0
# BUILDINGS              157092.0  40392.0
# BUSINESS AFFAIRS       157092.0  38376.0
# CITY CLERK             133545.0  38376.0
# CITY COUNCIL           168264.0  12840.0
# COMMUNITY DEVELOPMENT  175020.0  42108.0
# COPA                   161856.0  31872.0
# CULTURAL AFFAIRS       155040.0  19250.0
# DISABILITIES           138420.0  38100.0
# DoIT                   154992.0  60972.0
# FAMILY & SUPPORT       175002.0  36204.0
# FINANCE                165000.0  36204.0
# FIRE                   202728.0  37980.0
# GENERAL SERVICES       163896.0  33552.0
# HEALTH                 190750.0  38376.0
# HUMAN RELATIONS        125004.0  70620.0
# ...

# %%
fk = new_filter.groupby('Department')['annualized'].agg(['min', 'max'])

# %%
fk
# Out:
#                            min       max
# Department
# ADMIN HEARNG           41640.0  156420.0
# ANIMAL CONTRL          41832.0  130008.0
# AVIATION               22750.0  300000.0
# BOARD OF ELECTION      27912.0  133740.0
# BOARD OF ETHICS        73944.0  135672.0
# BUDGET & MGMT          22750.0  169992.0
# BUILDINGS              40392.0  157092.0
# BUSINESS AFFAIRS       38376.0  157092.0
# CITY CLERK             38376.0  133545.0
# CITY COUNCIL           12840.0  168264.0
# COMMUNITY DEVELOPMENT  42108.0  175020.0
# COPA                   31872.0  161856.0
# CULTURAL AFFAIRS       19250.0  155040.0
# DISABILITIES           38100.0  138420.0
# DoIT                   60972.0  154992.0
# FAMILY & SUPPORT       36204.0  175002.0
# FINANCE                36204.0  165000.0
# FIRE                   37980.0  202728.0
# GENERAL SERVICES       33552.0  163896.0
# HEALTH                 38376.0  190750.0
# HUMAN RELATIONS        70620.0  125004.0
# ...

# %%
new_filter.groupby('Department')['annualized'].sum().sort_values(ascending=False).head(5)
# Out:
# Department
# POLICE           1.159264e+09
# FIRE             4.545907e+08
# WATER MGMNT      1.605155e+08
# STREETS & SAN    1.431378e+08
# AVIATION         1.193267e+08
# Name: annualized, dtype: float64

# %%
new_filter.groupby('Department')['annualized'].sum().sort_values(ascending=True).head(5)
# Out:
# Department
# LICENSE APPL COMM      84420.0
# POLICE BOARD          172272.0
# BOARD OF ETHICS       760488.0
# HUMAN RELATIONS      1517112.0
# TREASURER            2020323.0
# Name: annualized, dtype: float64

# %%
my_filter=salary_list[salary_list['Full or Part-Time'] == 'P']

# %%
my_filter
# Out:
#                         Name                          Job Titles  \
# 30765      BANNON,  EDWARD L                     ALDERMANIC AIDE
# 30842  MCLAUGHLIN,  TERESA B   COORD OF ECON DEV II - PLNG & DEV
# 30886      GONZALEZ,  NELIA                      ALDERMANIC AIDE
# 30912       COOPER,  EMILY J  COMMUNITY LIVING SPECIALIST-HOURLY
# 30913   THOMPSON,  CHANDRA D  COMMUNITY LIVING SPECIALIST-HOURLY
# ...                      ...                                 ...
# 33178         XIE,  DE KUAN                   FOSTER GRANDPARENT
# 33179   YASHCENKO,  LARISA V                    SENIOR COMPANION
# 33180            YE,  SONG D                    SENIOR COMPANION
# 33181        YOUNG,  AMANDA                   FOSTER GRANDPARENT
# 33182            YU,  MING Z                    SENIOR COMPANION
#
#                   Department Full or Part-Time Salary or Hourly  \
# 30765           CITY COUNCIL                 P           Hourly
# ...

# %%
my_filter.groupby('Department')

# %%
my_filter.groupby('Department')['annualized'].sum().to_frame().reset_index().sort_values(by='annualized')
# Out:
#                Department  annualized
# 8                     LAW     14510.0
# 9          MAYOR'S OFFICE     20000.0
# 6                 FINANCE     28000.0
# 7         HUMAN RESOURCES     55000.0
# 4   COMMUNITY DEVELOPMENT     78960.0
# 11                 POLICE     93840.0
# 2        BUSINESS AFFAIRS     96380.0
# 1                AVIATION    402300.0
# 0           ANIMAL CONTRL    444560.0
# 3            CITY COUNCIL    782230.0
# 5        FAMILY & SUPPORT   1510900.0
# 13          STREETS & SAN   2550740.0
# 12         PUBLIC LIBRARY   4573510.0
# 10                   OEMC  22774880.0

# %%
my_filter.nlargest(5,'annualized')
# Out:
#                         Name                          Job Titles  \
# 30765      BANNON,  EDWARD L                     ALDERMANIC AIDE
# 30842  MCLAUGHLIN,  TERESA B   COORD OF ECON DEV II - PLNG & DEV
# 30886      GONZALEZ,  NELIA                      ALDERMANIC AIDE
# 30912       COOPER,  EMILY J  COMMUNITY LIVING SPECIALIST-HOURLY
# 30913   THOMPSON,  CHANDRA D  COMMUNITY LIVING SPECIALIST-HOURLY
#
#                   Department Full or Part-Time Salary or Hourly  \
# 30765           CITY COUNCIL                 P           Hourly
# 30842  COMMUNITY DEVELOPMENT                 P           Hourly
# 30886           CITY COUNCIL                 P           Hourly
# 30912       FAMILY & SUPPORT                 P           Hourly
# 30913       FAMILY & SUPPORT                 P           Hourly
#
#        Typical Hours  Annual Salary  Hourly Rate  annualized
# 30765           35.0            NaN        22.00     38500.0
# 30842           20.0            NaN        36.75     36750.0
# ...

# %%
y=my_filter.groupby('Department')

# %%
y.head
# Out:
# <bound method GroupBy.head of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x113c87790>>

# %%
new=salary_list['Department']

# %%
new
# Out:
# 0                AVIATION
# 1                  POLICE
# 2          MAYOR'S OFFICE
# 3                    FIRE
# 4                    FIRE
#                ...
# 33178    FAMILY & SUPPORT
# 33179    FAMILY & SUPPORT
# 33180    FAMILY & SUPPORT
# 33181    FAMILY & SUPPORT
# 33182    FAMILY & SUPPORT
# Name: Department, Length: 33183, dtype: object

# %%
my_filter.groupby(new)

# %%
my_filter['Department'].value_counts()
# Out:
# OEMC                     1229
# PUBLIC LIBRARY            288
# FAMILY & SUPPORT          286
# STREETS & SAN             174
# CITY COUNCIL               51
# ANIMAL CONTRL              19
# AVIATION                   18
# POLICE                     10
# BUSINESS AFFAIRS            7
# HUMAN RESOURCES             4
# COMMUNITY DEVELOPMENT       3
# FINANCE                     2
# LAW                         1
# MAYOR'S OFFICE              1
# Name: Department, dtype: int64

# %%
counts = my_filter['Department'].value_counts()

# %%
percent = my_filter['Department'].value_counts(normalize=True)

# %%
percent100 = my_filter['Department'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'

# %%
pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
# Out:
#                        counts       per per100
# OEMC                     1229  0.587195  58.7%
# PUBLIC LIBRARY            288  0.137602  13.8%
# FAMILY & SUPPORT          286  0.136646  13.7%
# STREETS & SAN             174  0.083134   8.3%
# CITY COUNCIL               51  0.024367   2.4%
# ANIMAL CONTRL              19  0.009078   0.9%
# AVIATION                   18  0.008600   0.9%
# POLICE                     10  0.004778   0.5%
# BUSINESS AFFAIRS            7  0.003344   0.3%
# HUMAN RESOURCES             4  0.001911   0.2%
# COMMUNITY DEVELOPMENT       3  0.001433   0.1%
# FINANCE                     2  0.000956   0.1%
# LAW                         1  0.000478   0.0%
# MAYOR'S OFFICE              1  0.000478   0.0%

# %%
salary_list['Full or Part-Time']
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        F
#         ..
# 33178    P
# 33179    P
# 33180    P
# 33181    P
# 33182    P
# Name: Full or Part-Time, Length: 33183, dtype: object

# %%
salary_list['Full or Part-Time'].dtypes
# Out:
# dtype('O')

# %%
salary_list['Full or Part-Time'].describe
# Out:
# <bound method NDFrame.describe of 0        F
# 1        F
# 2        F
# 3        F
# 4        F
#         ..
# 33178    P
# 33179    P
# 33180    P
# 33181    P
# 33182    P
# Name: Full or Part-Time, Length: 33183, dtype: object>
